# %%
WSGI- web Server gateway Interface
Jinja2 template Engine
Flask is a webframe work created with the help of python prog lang


flask is used to create a web app



                                                wsgi
req1,req2,req3 --------------->webserver<---------------------> web app
jinja2 template engine ---> it is a web template engine 
it combines a webtemplate with datasource


datasource <-----------------------> webtemplate

database
data
mlmodel
finally create  a dynamic web pages
# Out:
#   Cell In[4], line 1
#     WSGI- web Server gateway Interface
#               ^
# SyntaxError: invalid syntax
