# %%
# core components of mlflow
# why use mlflow
# who uses mlflow
# usecase of mlflow

# %%
# Life cycle of ds project

# Data Preparation
# EDA
# Feature engineering
# Model training
# Model Validation
# Deployment
# Monitoring

# %%
# Data scientist leverages mlflow for

# Experiment tracking and hypothesis testing + versioning
# Code Structuring
# Model Packaging and dependency management
# Evaluating hyper parameter tuning  // tacking hyperparameter tuning with all combinations and visualization graphs
# compare the rsults of models retaining over time

# %%
# MLOps Professional

# They manage the lifecycle of trained models in both pre and post Deployment
# deploy models securily to the producton Environment
# manage deployment dependencies

# %%
# prompt engineer users:

# Evaluate and experiment with large language models
# create custom prompts and experiments
# deciding on the bestbase model suitable for project requirements

# %%
# Mlflow usecases:

# Experiment tracking: Trace parameters and metrics -> UI
# Model selection and deployment
# model perfoemance monitoring
# collaborative projects

# %% [markdown]
# ## MLFLOW TRACKING SERVER

# %%
import mlflow
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("CHECK LOCAL HOST CONNECTION")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("abdul",2)
# Out:
# 2026/08/17 11:00:23 INFO mlflow.tracking.fluent: Experiment with name 'CHECK LOCAL HOST CONNECTION' does not exist. Creating a new experiment.
# 🏃 View run fun-crow-289 at: http://127.0.0.1:5000/#/experiments/1/runs/8a2b25c93c0d4360b8fc8c616f69de59
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("abdul1",2)
# Out:
# 🏃 View run magnificent-bat-131 at: http://127.0.0.1:5000/#/experiments/1/runs/86706c8276a64f1a8f97506037df3247
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("abdul2",2)
# Out:
# 🏃 View run debonair-rat-567 at: http://127.0.0.1:5000/#/experiments/1/runs/aa66de5d426d44e99c06df0dd7d1bb7c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
