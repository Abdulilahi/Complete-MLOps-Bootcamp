# %%
class dobexception(Exception):
    pass

# %%
year=int(input("enter your dob:"))
age=2026-year
try:
    if(age>20):
        print("you are eligible")
    else:
        raise dobexception
except dobexception:
    print("you age is not satisfied for this arena")
# Out:
# you are eligible
